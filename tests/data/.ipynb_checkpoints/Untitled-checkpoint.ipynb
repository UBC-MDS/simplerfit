# %%
library(tidyverse)
adult <- read_csv("adult.csv")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Rows: 32561 Columns: 15
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): workclass, education, marital.status, occupation, relationship, rac...
# dbl (6): age, fnlwgt, education.num, capital.gain, capital.loss, hours.per.week
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# adult

# %%
data_long <-  adult|> 
    select_if(is.numeric) |>
    pivot_longer(everything())

# %%
data_long
# Out:
#        name           value
# 1      age                90
# 2      fnlwgt          77053
# 3      education.num       9
# 4      capital.gain        0
# 5      capital.loss     4356
# 6      hours.per.week     40
# 7      age                82
# 8      fnlwgt         132870
# 9      education.num       9
# 10     capital.gain        0
# 11     capital.loss     4356
# 12     hours.per.week     18
# 13     age                66
# 14     fnlwgt         186061
# 15     education.num      10
# 16     capital.gain        0
# 17     capital.loss     4356
# 18     hours.per.week     40
# 19     age                54
# 20     fnlwgt         140359
# 21     education.num       4
# 22     capital.gain        0
# 23     capital.loss     3900
# 24     hours.per.week     40
# 25     age                41
# 26     fnlwgt         264663
# 27     education.num      10
# 28     capital.gain        0
# 29     capital.loss     3900
# 30     hours.per.week     40
# ⋮      ⋮              ⋮
# 195337 age                22
# 195338 fnlwgt         310152
# 195339 education.num      10
# 195340 capital.gain        0
# 195341 capital.loss        0
# 195342 hours.per.week     40
# 195343 age                27
# 195344 fnlwgt         257302
# 195345 education.num      12
# 195346 capital.gain        0
# 195347 capital.loss        0
# 195348 hours.per.week     38
# 195349 age                40
# 195350 fnlwgt         154374
# 195351 education.num       9
# 195352 capital.gain        0
# 195353 capital.loss        0
# 195354 hours.per.week     40
# 195355 age                58
# 195356 fnlwgt         151910
# 195357 education.num       9
# 195358 capital.gain        0
# 195359 capital.loss        0
# 195360 hours.per.week     40
# 195361 age                22
# 195362 fnlwgt         201490
# 195363 education.num       9
# 195364 capital.gain        0
# 195365 capital.loss        0
# 195366 hours.per.week     20

# %%
# melt_df

# %%
plot <- ggplot2::ggplot(data_long, ggplot2::aes(x = value, color="target"))+
      ggplot2::facet_wrap(~name, scales = "free_x") +
      ggplot2::geom_density()

# %%
plot
# Out:
# plot without title

# %%
plot_distributions <- function(df, bins = 40, hist_cols=NULL, density=FALSE){
  if (!is.null(hist_cols)){
      
    data_long <-  df|> 
    select_if(is.numeric) |>
    pivot_longer(hist_cols)
  }
  else{
    data_long <-  df|> 
    select_if(is.numeric) |>
    pivot_longer(everything())
  }
    

  if(!density){
  plot_hist <- ggplot2::ggplot(data_long, ggplot2::aes(x = value))+
    ggplot2::facet_wrap(~name, scales = "free_x") +
    ggplot2::geom_histogram(bins=bins) }
    else{
    plot_hist <- ggplot2::ggplot(data_long, ggplot2::aes(x = value))+
    ggplot2::facet_wrap(~name, scales = "free_x") +
    ggplot2::geom_density(fill="green")
    
    }
plot_hist
}

# %%
x=plot_distributions(data, density=TRUE)

# %%
x
# Out:
# plot without title

# %%
# GGally::ggcorr(data)
# GGally::ggcorr(data, method = c("everything", "pearson"))

# %%
GGally::ggcorr(data,low = "steelblue", mid = "white", high = "darkred", label=TRUE,method = c("everything", "pearson") )
# Out:
# Warning message in GGally::ggcorr(data, low = "steelblue", mid = "white", high = "darkred", :
# “data in column(s) 'workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country', 'income' are not numeric and were ignored”
# plot without title

# %%
plot_corr <- function(data, corr='pearson', pair_cols=NULL){
  if(!is.null(pair_cols)){
    
    data <- data |> 
            select(pair_cols)
  }
  corr_plot <- GGally::ggcorr(data,low = "steelblue", mid = "white", high = "darkred", label=TRUE,method = c("everything", corr) )
  corr_plot

}

# %%
plot_corr(data)
# Out:
# Warning message in GGally::ggcorr(data, low = "steelblue", mid = "white", high = "darkred", :
# “data in column(s) 'workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country', 'income' are not numeric and were ignored”
# plot without title

# %%
library(tidyverse)
spotify <- read_csv("SpotifyFeatures.csv")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Rows: 232725 Columns: 18
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (7): genre, artist_name, track_name, track_id, key, mode, time_signature
# dbl (11): popularity, acousticness, danceability, duration_ms, energy, instr...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
library(GGally)

plot_splom <- function(data, cols=NULL){
  if(!is.null(cols)){

  data <- data |>
        dplyr::select(cols)
  }

  splom_plot <- GGally::ggpairs(data |> select_if(is.numeric), progress = FALSE)
  splom_plot
}

# %%
# plot_splom(spotify, cols = c('acousticness', 'loudness', 'danceability'), categorical_col=c('genre'))

# %%
# spotify <- spotify |> select(!genre)
# GGally::ggpairs(spotify|> select_if(is.numeric), progress = FALSE)

# %%
plot_splom(spotify, cols=c("acousticness", "loudness", "danceability"))
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(cols)` instead of `cols` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# plot without title
